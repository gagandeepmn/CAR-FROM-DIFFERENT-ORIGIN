# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv(r'45.csv')
d
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
d.shape
# Out:
# (428, 15)

# %%
d.size
# Out:
# 6420

# %%
d.head()
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945  $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820  $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990  $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195  $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755  $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186
# 4        115     197

# %%
d.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
d['Cylinders'].fillna(d['Cylinders'].mean(),  inplace=True)

# %%
d
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
d['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Chrysler         15
# Volkswagen       15
# Mitsubishi       13
# Dodge            13
# Jaguar           12
# Hyundai          12
# Volvo            12
# Lexus            11
# Kia              11
# Mazda            11
# Pontiac          11
# Subaru           11
# Mercury           9
# Lincoln           9
# Buick             9
# Suzuki            8
# Cadillac          8
# GMC               8
# Saturn            8
# Infiniti          8
# Saab              7
# Acura             7
# Porsche           7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Isuzu             2
# Scion             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
d[d['Origin'].isin(['Asia','Europe'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
d[(d['Weight']>600)]
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
d['MPG_City']=d['MPG_City'].apply(lambda x:x-3)

# %%
d
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
d.groupby('Origin').Cylinders.value_counts()
# Out:
# Origin  Cylinders
# Asia    4.000000     74
#         6.000000     69
#         8.000000     12
#         5.807512      2
#         3.000000      1
# Europe  6.000000     54
#         8.000000     34
#         4.000000     25
#         5.000000      7
#         12.000000     3
# USA     6.000000     67
#         8.000000     41
#         4.000000     37
#         10.000000     2
# Name: Cylinders, dtype: int64

# %%
(d
 .groupby('Origin')
 .Cylinders
 .value_counts()
 .unstack()
 .fillna(0)
)
# Out:
# Cylinders  3.0   4.0   5.0   6.0   8.0   10.0  12.0
# Origin
# Asia        1.0  74.0   0.0  69.0  12.0   0.0   0.0
# Europe      0.0  25.0   7.0  54.0  34.0   0.0   3.0
# USA         0.0  37.0   0.0  67.0  41.0   2.0   0.0

# %%
origin_cyl=(d
 .groupby('Origin')
 .Cylinders
 .value_counts()
 .unstack()
 .fillna(0)
)

# %%
sns.heatmap(origin_cyl);

# %%
e=pd.crosstab(d['Type'],d['MPG_Highway'].mean())
e
# Out:
# col_0   26.843458
# Type
# Hybrid          3
# SUV            60
# Sedan         262
# Sports         49
# Truck          24
# Wagon          30

# %%
sns.catplot(data=e);

# %%
e1=pd.crosstab(d['Make'],d['MPG_City'].max())
e1
# Out:
# col_0          60
# Make
# Acura           7
# Audi           19
# BMW            20
# Buick           9
# Cadillac        8
# Chevrolet      27
# Chrysler       15
# Dodge          13
# Ford           23
# GMC             8
# Honda          17
# Hummer          1
# Hyundai        12
# Infiniti        8
# Isuzu           2
# Jaguar         12
# Jeep            3
# Kia            11
# Land Rover      3
# Lexus          11
# Lincoln         9
# MINI            2
# Mazda          11
# Mercedes-Benz  26
# Mercury         9
# Mitsubishi     13
# Nissan         17
# Oldsmobile      3
# Pontiac        11
# Porsche         7
# Saab            7
# Saturn          8
# Scion           2
# Subaru         11
# Suzuki          8
# Toyota         28
# Volkswagen     15
# Volvo          12
